# %% [markdown]
# Cleaning product_dirty file

# %%
import pandas as pd
df =  pd.read_csv("products_dirty.csv")
df
# Out:
#      product_id                      product_name   price    cogs  category_id
# 0             1             Apple AirPods 3rd Gen     NaN   78.00          NaN
# 1             2                 Apple AirPods Max  549.99  231.00          1.0
# 2             3                 Apple AirPods Pro     NaN  112.50          NaN
# 3             4         Apple AirPods Pro 2nd Gen     NaN   17.50          1.0
# 4             5  Apple AirPods Pro 2nd Generation  249.99   20.00          1.0
# ..          ...                               ...     ...     ...          ...
# 760         761                 Sports Hand Grips   16.99    5.44          6.0
# 761         762              Baseball Batting Tee   59.99    7.80          6.0
# 762         763                Foldable Bike Rack   49.99   18.50          6.0
# 763         764                   Exercise Roller   24.99    5.50          6.0
# 764         765                         Golf Cart     NaN   35.00          6.0
#
# [765 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    765 non-null    int64
#  1   product_name  765 non-null    object
#  2   price         689 non-null    float64
#  3   cogs          765 non-null    float64
#  4   category_id   689 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 30.0+ KB

# %%
df.rename(columns={'cogs': 'Direct cost'},inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    765 non-null    int64
#  1   product_name  765 non-null    object
#  2   price         689 non-null    float64
#  3   Direct cost   765 non-null    float64
#  4   category_id   689 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 30.0+ KB

# %%
df
# Out:
#      product_id                      product_name   price  Direct cost  \
# 0             1             Apple AirPods 3rd Gen     NaN        78.00
# 1             2                 Apple AirPods Max  549.99       231.00
# 2             3                 Apple AirPods Pro     NaN       112.50
# 3             4         Apple AirPods Pro 2nd Gen     NaN        17.50
# 4             5  Apple AirPods Pro 2nd Generation  249.99        20.00
# ..          ...                               ...     ...          ...
# 760         761                 Sports Hand Grips   16.99         5.44
# 761         762              Baseball Batting Tee   59.99         7.80
# 762         763                Foldable Bike Rack   49.99        18.50
# 763         764                   Exercise Roller   24.99         5.50
# 764         765                         Golf Cart     NaN        35.00
#
#      category_id
# 0            NaN
# 1            1.0
# 2            NaN
# 3            1.0
# 4            1.0
# ..           ...
# 760          6.0
# 761          6.0
# 762          6.0
# 763          6.0
# 764          6.0
#
# [765 rows x 5 columns]

# %%
df = df.dropna(subset=['category_id', 'price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619 entries, 1 to 763
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    619 non-null    int64
#  1   product_name  619 non-null    object
#  2   price         619 non-null    float64
#  3   Direct cost   619 non-null    float64
#  4   category_id   619 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 29.0+ KB

# %%
df.to_csv('product_clean_data.csv' , index = False)

# %% [markdown]
# Cleaning Shipping_dirty File

# %%
import pandas as pd
df = pd.read_csv('shipping.csv')
df
# Out:
#        shipping_id  order_id shipping_date return_date shipping providers  \
# 0                1      7136    2024-01-07         NaN                dhl
# 1                2      1107    2023-06-22         NaN           bluedart
# 2                3      2787    2023-01-01         NaN              fedex
# 3                4      1033    2022-11-25         NaN              fedex
# 4                5     19241    2022-09-13         NaN              fedex
# ...            ...       ...           ...         ...                ...
# 21136        21137      1321    2023-03-18         NaN           bluedart
# 21137        21138     16342    2021-08-30         NaN           bluedart
# 21138        21139     18881    2021-06-06         NaN           bluedart
# 21139        21140      9834    2020-07-14         NaN           bluedart
# 21140        21141      5515    2020-03-01         NaN           bluedart
#
#       delivery_status
# 0           Delivered
# 1           Delivered
# 2           Delivered
# 3           Delivered
# 4           Delivered
# ...               ...
# 21136         Shipped
# 21137         Shipped
# 21138         Shipped
# 21139         Shipped
# 21140         Shipped
#
# [21141 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21141 entries, 0 to 21140
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shipping_id         21141 non-null  int64
#  1   order_id            21141 non-null  int64
#  2   shipping_date       21141 non-null  object
#  3   return_date         2840 non-null   object
#  4   shipping providers  21141 non-null  object
#  5   delivery_status     21141 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 991.1+ KB

# %%
df.rename(columns={'shipping providers':'Delivery_Services'},inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21141 entries, 0 to 21140
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shipping_id        21141 non-null  int64
#  1   order_id           21141 non-null  int64
#  2   shipping_date      21141 non-null  object
#  3   return_date        2840 non-null   object
#  4   Delivery_Services  21141 non-null  object
#  5   delivery_status    21141 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 991.1+ KB

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21141 entries, 0 to 21140
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shipping_id        21141 non-null  int64
#  1   order_id           21141 non-null  int64
#  2   shipping_date      21141 non-null  object
#  3   return_date        2840 non-null   object
#  4   Delivery_Services  21141 non-null  object
#  5   delivery_status    21141 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 991.1+ KB

# %%
df['return_date'] = df['return_date'].fillna('Not Applicable')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21141 entries, 0 to 21140
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shipping_id        21141 non-null  int64
#  1   order_id           21141 non-null  int64
#  2   shipping_date      21141 non-null  object
#  3   return_date        21141 non-null  object
#  4   Delivery_Services  21141 non-null  object
#  5   delivery_status    21141 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 991.1+ KB

# %%
df
# Out:
#        shipping_id  order_id shipping_date     return_date Delivery_Services  \
# 0                1      7136    2024-01-07  Not Applicable               dhl
# 1                2      1107    2023-06-22  Not Applicable          bluedart
# 2                3      2787    2023-01-01  Not Applicable             fedex
# 3                4      1033    2022-11-25  Not Applicable             fedex
# 4                5     19241    2022-09-13  Not Applicable             fedex
# ...            ...       ...           ...             ...               ...
# 21136        21137      1321    2023-03-18  Not Applicable          bluedart
# 21137        21138     16342    2021-08-30  Not Applicable          bluedart
# 21138        21139     18881    2021-06-06  Not Applicable          bluedart
# 21139        21140      9834    2020-07-14  Not Applicable          bluedart
# 21140        21141      5515    2020-03-01  Not Applicable          bluedart
#
#       delivery_status
# 0           Delivered
# 1           Delivered
# 2           Delivered
# 3           Delivered
# 4           Delivered
# ...               ...
# 21136         Shipped
# 21137         Shipped
# 21138         Shipped
# 21139         Shipped
# 21140         Shipped
#
# [21141 rows x 6 columns]

# %%
df.to_csv('shipping_clean_data.csv' , index = False)

# %% [markdown]
# Cleaning inventory_dirty file

# %%
import pandas as pd
df = pd.read_csv('inventory_dirty.csv')
df
# Out:
#      inventory_id  product_id  stock  warehouse_id last_stock_date
# 0               1           1     55             1      2024-04-08
# 1               2           2     39             1      2024-02-02
# 2               3           3     92             1      2024-05-10
# 3               4           4     57             1      2024-04-18
# 4               5           5     87             1      01-09-2024
# ..            ...         ...    ...           ...             ...
# 760           761         761     22             1      2023-08-21
# 761           762         762      5             1      2022-11-14
# 762           763         763     18             1      2022-12-13
# 763           764         764     21             1      2022-01-06
# 764           765         765     23             1      2022-01-01
#
# [765 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   inventory_id     765 non-null    int64
#  1   product_id       765 non-null    int64
#  2   stock            765 non-null    int64
#  3   warehouse_id     765 non-null    int64
#  4   last_stock_date  765 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 30.0 KB

# %%
df['last_stock_date'] = pd.to_datetime(df['last_stock_date'], format='mixed', dayfirst=True)

# %%
df
# Out:
#      inventory_id  product_id  stock  warehouse_id last_stock_date
# 0               1           1     55             1      2024-04-08
# 1               2           2     39             1      2024-02-02
# 2               3           3     92             1      2024-05-10
# 3               4           4     57             1      2024-04-18
# 4               5           5     87             1      2024-09-01
# ..            ...         ...    ...           ...             ...
# 760           761         761     22             1      2023-08-21
# 761           762         762      5             1      2022-11-14
# 762           763         763     18             1      2022-12-13
# 763           764         764     21             1      2022-01-06
# 764           765         765     23             1      2022-01-01
#
# [765 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   inventory_id     765 non-null    int64
#  1   product_id       765 non-null    int64
#  2   stock            765 non-null    int64
#  3   warehouse_id     765 non-null    int64
#  4   last_stock_date  765 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 30.0 KB

# %%
df.to_csv('inventory_clean_data.csv' , index=False)

# %% [markdown]
# Cleaning customers_dirty file

# %%
import pandas as pd 
df = pd.read_csv('customers_dirty.csv')
df
# Out:
#      Customer ID first_name last_name      state
# 0            894     Ursula       Lee  Wisconsin
# 1            895     Samuel     Clark  Wisconsin
# 2            896    Patrick     Scott  Wisconsin
# 3            897        Mia     Davis  wIscoNsIn
# 4            898       Jake     Davis  Wisconsin
# ..           ...        ...       ...        ...
# 893            1       John     Smith    Alabama
# 894            2      Wanda    Fisher    Alabama
# 895            3       Tara     Green    Alabama
# 896            4      Quinn   Johnson    Alabama
# 897            5       Noah     Green    Alabama
#
# [898 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  898 non-null    int64
#  1   first_name   898 non-null    object
#  2   last_name    898 non-null    object
#  3   state        898 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 28.2+ KB

# %%
df['Name'] = df['first_name'] + ' ' + df['last_name']

# %%
df.head()
# Out:
#    Customer ID first_name last_name      state           Name
# 0          894     Ursula       Lee  Wisconsin     Ursula Lee
# 1          895     Samuel     Clark  Wisconsin   Samuel Clark
# 2          896    Patrick     Scott  Wisconsin  Patrick Scott
# 3          897        Mia     Davis  wIscoNsIn      Mia Davis
# 4          898       Jake     Davis  Wisconsin     Jake Davis

# %%
df.drop(['first_name', 'last_name'], axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  898 non-null    int64
#  1   state        898 non-null    object
#  2   Name         898 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 21.2+ KB

# %%
df['state'] = df['state'].str.strip().str.title()

# %%
df.to_csv('customer_clean_data.csv' , index=False)

# %% [markdown]
# Cleaning orders_dirty file

# %%
import pandas as pd
df = pd.read_csv("orders_dirty.csv")
df
# Out:
#        order_id  order_date  customer_id  seller_id order_status
# 0          5893  2023-11-27           50          5   Inprogress
# 1          4071  29/08/2023           50          5   Inprogress
# 2          3721  2023-08-02           50          2   Inprogress
# 3          4631  2022-01-01           50          5   Inprogress
# 4          2069  2021-11-21           50          5   Inprogress
# ...         ...         ...          ...        ...          ...
# 22705      3816         NaN          605          1    COMPLeTed
# 22706      9124  2020-11-24          692          5     Returned
# 22707      1041  2023-08-08          550          5    cOMPlEted
# 22708     15130         NaN          616         44    Completed
# 22709     12921  2023-04-22          635         16    Completed
#
# [22710 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21949 entries, 0 to 22706
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      21949 non-null  int64
#  1   order_date    21949 non-null  datetime64[ns]
#  2   customer_id   21949 non-null  int64
#  3   seller_id     21949 non-null  int64
#  4   order_status  21949 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 1.0+ MB

# %%
df['order_status'] = df['order_status'].str.strip().str.title()

# %%
df.drop_duplicates(inplace = True)

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=True)

# %%
df['order_date'].isna().sum()
# Out:
# 2163

# %%
median_value = df['order_date'].median()
df['order_date'] = df['order_date'].fillna(median_value)

# %%
df.to_csv('orders_clean_data.csv' , index=False)

# %% [markdown]
# Cleaning order_items_dirty file

# %%
import pandas as pd
df = pd.read_csv('order_items_dirty.csv')
df
# Out:
#        order_item_id  order_id  product_id  quantity  price_per_unit
# 0              19730     19730           6         1         1299.99
# 1              19558     19558           9         1          449.99
# 2              19563     19563           8         1         4999.99
# 3              18810     18810           9         1          449.99
# 4              19949     19949           9         1          449.99
# ...              ...       ...         ...       ...             ...
# 22705           4243      4243         225         1          999.99
# 22706          19697     19697           9         1          449.99
# 22707          16414     16414         736         2          129.99
# 22708           9500      9500         531         2             NaN
# 22709          19078     19078           2         1          549.99
#
# [22710 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21629 entries, 0 to 21628
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_item_id   21629 non-null  int64
#  1   order_id        21629 non-null  int64
#  2   product_id      21629 non-null  int64
#  3   quantity        21629 non-null  int64
#  4   price_per_unit  21629 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 1013.9 KB

# %%
df.drop_duplicates(inplace=True)

# %%
df['price_per_unit'].isna().sum()
# Out:
# 2163

# %%
df['price_per_unit'] = df['price_per_unit'].fillna(df['price_per_unit'].mean())

# %%
df.head()
# Out:
#    order_item_id  order_id  product_id  quantity  price_per_unit
# 0          19730     19730           6         1         1299.99
# 1          19558     19558           9         1          449.99
# 2          19563     19563           8         1         4999.99
# 3          18810     18810           9         1          449.99
# 4          19949     19949           9         1          449.99

# %%
df.to_csv('order_items_clean_data.csv' , index=False)
